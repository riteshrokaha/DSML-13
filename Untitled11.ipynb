# %% [markdown]
# <a href="https://colab.research.google.com/github/riteshrokaha/DSML-13/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5

# %%
a
# Out:
# 5

# %%
print(a)
# Out:
# 5

# %%
data ={
    "name":"Ram"
}

# %%
print(data)
# Out:
# {'name': 'Ram'}

# %%
data
# Out:
# {'name': 'Ram'}

# %%
1,2,3,4  #INTEGER
1.3,4.5 #FLOAT
2+3J    #COMPLEX
# Out:
# (2+3j)

# %%
#1 positive integer
#-1negative integer

# %%
a=5

# %%
type(5)
# Out:
# int

# %%
type(5)
# Out:
# int

# %%
a=10

# %%
print(a)
# Out:
# 5

# %% [markdown]
# pie=22/7

# %%
pie
# Out:
# 3.142857142857143

# %%
type(pie)
# Out:
# float

# %%
data=3+2j

# %%
print(data)
# Out:
# (3+2j)

# %%
type(data)
# Out:
# complex

# %%
age = 20.4
#type conversion

# %%
age=int(age)

# %%
print(age)
# Out:
# 20

# %%
income=200
new_income=float(income)
print(new_income)
type(new_income)
# Out:
# 200.0
# float

# %%
new_income=str(new_income)

# %%
new_income
# Out:
# '200.0'

# %%
type(new_income)
# Out:
# float

# %%
fruits=["Apple","Banana","Cherry"]
for fruits in fruits:
    print(fruits)
# Out:
# Apple
# Banana
# Cherry

# %%
marks=[10,20,30,40,50]
for mark in marks:
    print(mark)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
Subjects=["Math","Science","Nepali","Social Studies"]
for subject in Subjects:
    print(subject)
# Out:
# Math
# Science
# Nepali
# Social Studies

# %%
subject_scores={
    "Math":95,
    "Science":80,
    "Nepali":85,
    "Social Studies":60,

}

for subject, score in subject_scores.items():
    print(f"{subject}: {score}")
# Out:
# Math: 95
# Science: 80
# Nepali: 85
# Social Studies: 60

# %%
####for key, value in dictionary_name.items():

# %%
salaries={
    "Alice":70000,
    "Bob":90000,
    "Charlie":80000,
    "Natalie":70000

    }
for name, salary in salaries.items():
        print(f" {name}:earns ${salary}")
# Out:
#  Alice:earns $70000
#  Bob:earns $90000
#  Charlie:earns $80000
#  Natalie:earns $70000

# %%
student_grades = {"Alice": "A", "Bob": "B"}

#  Custom variable names           Matches dictionary name
#    👇       👇                        👇
for student, grade in student_grades.items():
    print(f"{student} got an {grade}")
# Out:
# Alice got an A
# Bob got an B

# %%
print(10)
# Out:
# 10

# %%
#print sum of two numbers
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a=b
b=10
print(a)
# Out:
# 20

# %%
''' My name is Ritesh.I live in Imadol.What is your name'''
# Out:
# ' My name is Ritesh.I live in Imadol.What is your name'

# %%
a= int(input("Enter a numbber"))
b=10
print(a+b)
# Out:
# Enter a numbber20
# 30

# %%
 a=10;
 A=20
 print(a,A)
# Out:
# 10 20

# %%
print(A,A)
# Out:
# 20 20

# %%
a=7
b=3
print(a+b)
# Out:
# 10

# %%
print(a-b)
# Out:
# 4

# %%
print(a*b)
# Out:
# 21

# %%
print(a/b)
# Out:
# 2.3333333333333335

# %%
print(a//b)
# Out:
# 2

# %%
print(a%b)
# Out:
# 1

# %%
print(a**b)
# Out:
# 343

# %%
Sequence_dishes=["Momo","Chowmein","Yogurt dessert"]
for food_items in Sequence_dishes:
    print(food_items)
# Out:
# Momo
# Chowmein
# Yogurt dessert

# %%
Name_of_dishes={
    "Momo":"7 plates",
    "Pizza":"4 boxes",
    "Lasagnia":"one plate",
    "Panipuri":"13 plates"
    }

for food_name, value in Name_of_dishes.items() :
        print(f"{food_name}: {value}")
# Out:
# Momo: 7 plates
# Pizza: 4 boxes
# Lasagnia: one plate
# Panipuri: 13 plates

# %%
is_learning=True

# %%
is_learning=7
while is_learning:
    print("You're learning")
# Out:
# Streaming output truncated to the last 5000 lines.
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# You're learning
# ...

# %%
a= 5
while a=5:
    print("I am reading Kite runner novel")
# Out:
# Streaming output truncated to the last 5000 lines.
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# ...

# %%
b= 56
while b=56:
    print("I am reading Alchemist novel")
# Out:
# Streaming output truncated to the last 5000 lines.
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# I am reading Kite runner novel
# ...

# %%
user_input=input("Enter a number")
if types p
   print(Hello)
else terminate
